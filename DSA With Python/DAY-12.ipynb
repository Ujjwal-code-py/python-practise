# %% [markdown]
# ## DAY-12

# %% [markdown]
# ## Two Sum

# %%
nums=[5,83,43,23,1,3,2,8,13]
target=9
def two_sum(nums, target):
    li=[]
    for i in range(len(nums)):
        for j in range(i+1,len(nums)):
            if nums[i]+nums[j]==target:
                li.append(i)
                li.append(j)
    return li
print(two_sum(nums,target))

## Brute force approach: O(n^2) time complexity
# Out:
# [4, 7]

# %%
## optimal
nums=[5,83,43,23,1,3,2,8,13]
target=9
a={}

for i in range(len(nums)): # TC=o(n)
    diff=target-nums[i]
    if diff in a: # TC o(1)
        print([a[diff],i])
        break 
    a[nums[i]]=i
     
## TC=o(n)
## SC=o(n)
# Out:
# [4, 7]
