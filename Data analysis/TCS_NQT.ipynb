# %%
a=list(map(int,input().split()))
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a=list(map(int,input().split()))[:5] # if you want only 5 elements
print(a)

# %%
a=[int(i) for i in input().split()[:5]] # using list comprehension
# sorting bubblesort
l=0
r=1
for i in range(len(a)):
    for j in range(i+1,len(a)):
        if(a[i]>a[j]):
            a[i],a[j]=a[j],a[i]
    
        
print(a)
# Out:
# [1, 2, 3, 12]

# %%
n=int(input())
# a=[i for i in range(len(n)+1)]
li=[]
for i in range(n):
    a=int(input())

    li.append(a)
print(li)
# Out:
# [2, 3, 4, 5]

# %%
# Demonstrating sorting options
# use .sort() to sort in-place or sorted() to return a new list
a = [3, 1, 4, 2, 5]
print("original:", a)

a.sort()
print("after a.sort():", a)

b = sorted(a, reverse=True)
print("using sorted(reverse=True):", b)

# %%
# manual sorting without built-in functions (simple bubble sort)
# bubble sort repeatedly steps through list,
# compares adjacent items and swaps them if they are in the wrong order.
# after each full pass, the largest remaining element "bubbles" to the end.
# the process is repeated until the list is sorted.

nums = [5, 2, 9, 1, 5, 6]
print("before manual sort:", nums)

for i in range(len(nums)):
    for j in range(0, len(nums)-i-1):
        if nums[j] > nums[j+1]:
            # swap
            nums[j], nums[j+1] = nums[j+1], nums[j]

print("after manual bubble sort:", nums)
